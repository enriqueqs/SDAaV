# %% [markdown]
# # Week 2
#
# ## Overview
#
# Ok, so we've made it to week 2. Today's lecture has 4 parts.
# * First, we'll go over some practical information.
# * Then we'll do a little data visualization exercise (which we'll come back to later in the semester).
# * As the main event, we will work with crime-data and generate a large number of interesting and informative plots.
# * Finally - in the last part - we'll play around with visualizing the geo-data contained in the CSV file.

# %% [markdown]
# ## Part 1: Some practical things
#
# The videos below contain important practical information, so - although I covered most of this in class last week - I recommend you watch them (it's sometimes good to hear things a second time). You don't necessarily have to start by watching these - it's something you can do if you need a break from coding

# %%
# Video 1. The structure of the course
from IPython.display import YouTubeVideo
YouTubeVideo("42KjmxgYYNI",width=800, height=450)

# %%
# Video 2: The assignments
YouTubeVideo("sSQBcbQ3FL0",width=800, height=450)

# %% [markdown]
# ## Part 2: A little visualization exercise
#
#
# > *Exercise*:
# >
# > Start by downloading these four datasets: [Data 1](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data1.tsv), [Data 2](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data2.tsv), [Data 3](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data3.tsv), and [Data 4](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data4.tsv). The format is `.tsv`, which stands for _tab separated values_.
# > Each file has two columns (separated using the tab character). The first column is $x$-values, and the second column is $y$-values.
# >
# > It's ok to just download these files to disk by right-clicking on each one, but if you use Python and _urllib_ or _urllib2_ to get them, I'll really be impressed. If you don't know how to do that, I recommend opening up Google and typing "download file using Python" or something like that. When interpreting the search results remember that _stackoverflow_ is your friend.
# >
# > * Using the `numpy` function `mean`, calculate the mean of both $x$-values and $y$-values for each dataset.
# > * Use python string formatting to print precisely two decimal places of these results to the output cell. Check out [this _stackoverflow_ page](http://stackoverflow.com/questions/8885663/how-to-format-a-floating-number-to-fixed-width-in-python) for help with the string formatting.
# > * Now calculate the variance for all of the various sets of $x$- and $y$-values (to three decimal places).
# > * Use `numpy` to calculate the [Pearson correlation](https://en.wikipedia.org/wiki/Pearson_product-moment_correlation_coefficient) between $x$- and $y$-values for all four data sets (also to three decimal places).
# > * The next step is use _linear regression_ to fit a straight line $f(x) = a x + b$ through each dataset and report $a$ and $b$ (to two decimal places). An easy way to fit a straight line in Python is using `scipy`'s `linregress`. It works like this
# > ```
# > from scipy import stats
# > slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
# >```
# > * Finally, it's time to plot the four datasets using `matplotlib.pyplot`. Use a two-by-two [`subplot`](http://matplotlib.org/examples/pylab_examples/subplot_demo.html) to put all of the plots nicely in a grid and use the same $x$ and $y$ range for all four plots. And include the linear fit in all four plots. (To get a sense of what I think the plot should look like, you can take a look at my version [here](https://raw.githubusercontent.com/suneman/socialdataanalysis2017/master/files/anscombe.png).)
# > * Explain - in your own words - what you think my point with this exercise is.
#
#
# Get more insight in the ideas behind this exercise by reading [here](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).
#
# And the video below generalizes in the coolest way imaginable. It's a treat, but don't watch it until **after** you've done the exercises.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * Using the numpy function mean, calculate the mean of both  𝑥 -values and  𝑦 -values for each dataset.
# * Use python string formatting to print precisely two decimal places of these results to the output cell. Check out this stackoverflow page for help with the string formatting.

# %%
d1 = np.genfromtxt(fname="data1.tsv", delimiter="\t")  
print("Mean of data 1 x = %.2f"%np.mean(d1[:,0]))
print("Mean of data 1, y = %.2f"%np.mean(d1[:,1]))
d2 = np.genfromtxt(fname="data2.tsv", delimiter="\t")  
print("Mean of data 2 x = %.2f"%np.mean(d2[:,0]))
print("Mean of data 2, y = %.2f"%np.mean(d2[:,1]))
d3 = np.genfromtxt(fname="data3.tsv", delimiter="\t") 
print("Mean of data 3 x = %.2f"%np.mean(d3[:,0]))
print("Mean of data 3, y = %.2f"%np.mean(d3[:,1]))
d4 = np.genfromtxt(fname="data4.tsv", delimiter="\t")  
print("Mean of data 4 x = %.2f"%np.mean(d4[:,0]))
print("Mean of data 4, y = %.2f"%np.mean(d4[:,1]))
# Out:
# Mean of data 1 x = 9.00
# Mean of data 1, y = 7.50
# Mean of data 2 x = 9.00
# Mean of data 2, y = 7.50
# Mean of data 3 x = 9.00
# Mean of data 3, y = 7.50
# Mean of data 4 x = 9.00
# Mean of data 4, y = 7.50

# %% [markdown]
# * Now calculate the variance for all of the various sets of  𝑥 - and  𝑦 -values (to three decimal places).

# %%
print("Variance of data 1 x = %.3f"%np.var(d1[:,0]))
print("Variance of data 1, y = %.3f"%np.var(d1[:,1]))
print("Variance of data 2 x = %.3f"%np.var(d2[:,0]))
print("Variance of data 2, y = %.3f"%np.var(d2[:,1]))
print("Variance of data 3 x = %.3f"%np.var(d3[:,0]))
print("Variance of data 3, y = %.3f"%np.var(d3[:,1]))
print("Variance of data 4 x = %.3f"%np.var(d4[:,0]))
print("Variance of data 4, y = %.3f"%np.var(d4[:,1]))
# Out:
# Variance of data 1 x = 10.000
# Variance of data 1, y = 3.752
# Variance of data 2 x = 10.000
# Variance of data 2, y = 3.752
# Variance of data 3 x = 10.000
# Variance of data 3, y = 3.748
# Variance of data 4 x = 10.000
# Variance of data 4, y = 3.748

# %% [markdown]
# * Use numpy to calculate the Pearson correlation between  𝑥 - and  𝑦 -values for all four data sets (also to three decimal places).

# %%
np.size(d1[:,0].T)
# Out:
# 11

# %%
np.set_printoptions(precision=3)
print("Pearson of data 1 =")
print(np.corrcoef(d1[:,0], d1[:,1]))
print("Pearson of data 2 =")
print(np.corrcoef(d2[:,0],d2[:,1]))
print("Pearson of data 3 =")
print(np.corrcoef(d3[:,0],d3[:,1]))
print("Pearson of data 4 =")
print(np.corrcoef(d4[:,0],d4[:,1]))
# Out:
# Pearson of data 1 =
# [[1.    0.816]
#  [0.816 1.   ]]
# Pearson of data 2 =
# [[1.    0.816]
#  [0.816 1.   ]]
# Pearson of data 3 =
# [[1.    0.816]
#  [0.816 1.   ]]
# Pearson of data 4 =
# [[1.    0.817]
#  [0.817 1.   ]]

# %% [markdown]
# * The next step is use _linear regression_ to fit a straight line $f(x) = a x + b$ through each dataset and report $a$ and $b$ (to two decimal places). An easy way to fit a straight line in Python is using `scipy`'s `linregress`. It works like this
# > ```
# > from scipy import stats
# > slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
# >```

# %%
from scipy import stats
slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(d1[:,0],d1[:,1])
print("Data 1 \n a = %.2f, b=%.2f"%(slope1,intercept1))
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(d2[:,0],d2[:,1])
print("Data 2 \n a = %.2f, b=%.2f"%(slope2,intercept2))
slope3, intercept3, r_value3, p_value3, std_err3 = stats.linregress(d3[:,0],d3[:,1])
print("Data 3 \n a = %.2f, b=%.2f"%(slope3,intercept3))
slope4, intercept4, r_value4, p_value4, std_err4 = stats.linregress(d4[:,0],d4[:,1])
print("Data 4 \n a = %.2f, b=%.2f"%(slope4,intercept4))
# Out:
# Data 1
#  a = 0.50, b=3.00
# Data 2
#  a = 0.50, b=3.00
# Data 3
#  a = 0.50, b=3.00
# Data 4
#  a = 0.50, b=3.00

# %% [markdown]
# * Finally, it's time to plot the four datasets using matplotlib.pyplot. Use a two-by-two subplot to put all of the plots nicely in a grid and use the same  𝑥  and  𝑦  range for all four plots. And include the linear fit in all four plots. (To get a sense of what I think the plot should look like, you can take a look at my version here.)

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(2, 15, 100)

plt.figure()
plt.subplot(2, 2, 1)
plt.scatter(d1[:,0], d1[:,1])
plt.plot(x, intercept1+slope1*x)


plt.subplot(2, 2, 2)
plt.scatter(d2[:,0], d2[:,1])
plt.plot(x, intercept2+slope2*x)


plt.subplot(2, 2, 3)
plt.scatter(d3[:,0], d3[:,1])
plt.plot(x, intercept3+slope3*x)


plt.subplot(2, 2, 4)
plt.scatter(d4[:,0], d4[:,1])
plt.plot(x, intercept4+slope4*x)


plt.show()

# %%
YouTubeVideo("DbJyPELmhJc",width=800, height=450)

# %% [markdown]
# ## Part 3: Working with the dataset
#
# The exercises today will continue to focus on the data in the big CSV file.
#
# Let's start by think a bit more about the crime-data file from San Francisco that you downloaded last week. We'll again only look at the focus-crimes.

# %%
focuscrimes = set(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])

# %% [markdown]
# > *Exercise*: More temporal patterns. Last time we plotted the development over time (how each of the focus crimes changed over time, year-by-year). Today we'll start by looking at the developments across the months, week and across the 24 hours of the day.
# > Again, restrict yourself to the dataset of entire years 2013-2018.
# >
# > * *Weekly patterns*. Basically, we'll forget about the yearly variation and just count up what happens during each weekday. [Here's what my version looks like](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/weekdays.png). Some things make sense - for example `drunkenness` and the weekend. But there are some aspects that were surprising to me. Check out `prostitution` and mid-week behavior, for example!?
# > * *The months*. We can also check if some months are worse by counting up number of crimes in Jan, Feb, ..., Dec. Did you see any surprises there?
# > * *The 24 hour cycle*. We'll can also forget about weekday and simply count up the number of each crime-type that occurs in the entire dataset from midnight to 1am, 1am - 2am ... and so on. Again: Give me a couple of comments on what you see.
# > * *Hours of the week*. But by looking at just 24 hours, we may be missing some important trends that can be modulated by week-day, so let's also check out the 168 hours of the week. So let's see the number of each crime-type Monday night from midninght to 1am, Monday night from 1am-2am - all the way to Sunday night from 11pm to midnight.

# %%
import pandas as pd

# %%
df = pd.read_csv('Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv')
df.head(10)
# Out:
#    IncidntNum        Category                 Descript  DayOfWeek        Date  \
# 0   146196161    NON-CRIMINAL            LOST PROPERTY    Tuesday  09/23/2014
# 1   150045675         ASSAULT                  BATTERY   Thursday  01/15/2015
# 2   140632022  SUSPICIOUS OCC  INVESTIGATIVE DETENTION  Wednesday  07/30/2014
# 3   150383259         ASSAULT                  BATTERY   Saturday  05/02/2015
# 4    40753980  OTHER OFFENSES         RECKLESS DRIVING     Friday  07/02/2004
# 5    40855122         SUICIDE       SUICIDE BY JUMPING    Tuesday  07/27/2004
# 6    66085191    NON-CRIMINAL            LOST PROPERTY     Sunday  11/19/2006
# 7    50908404   VEHICLE THEFT        STOLEN AUTOMOBILE   Saturday  08/13/2005
# 8    90768064           ARSON       ARSON OF A VEHICLE    Tuesday  07/28/2009
# 9   111027676         ASSAULT                  BATTERY   Saturday  12/24/2011
#
#     Time  PdDistrict      Resolution                   Address           X  \
# 0  01:00    SOUTHERN            NONE    800 Block of BRYANT ST -122.403405
# 1  17:00     TARAVAL            NONE  1800 Block of VICENTE ST -122.485604
# 2  09:32     BAYVIEW            NONE  100 Block of GILLETTE AV -122.396535
# 3  23:10     BAYVIEW  ARREST, BOOKED   2400 Block of PHELPS ST -122.400131
# 4  13:43     BAYVIEW            NONE   I-280 / CESAR CHAVEZ ST -120.500000
# 5  15:19    SOUTHERN            NONE         500 Block of I-80 -122.386667
# 6  17:45     BAYVIEW            NONE      0 Block of GIANTS DR -122.387501
# 7  17:00  TENDERLOIN            NONE  JENNINGS CT / INGALLS ST -120.500000
# 8  23:26     BAYVIEW            NONE     SELBY ST / OAKDALE AV -122.399686
# 9  07:00    SOUTHERN            NONE        0 Block of DORE ST -122.412933
#
#            Y                                    Location            PdId
# 0  37.775421   POINT (-122.403404791479 37.775420706711)  14619616171000
# 1  37.738821   POINT (-122.48560378101 37.7388214326705)  15004567504134
# 2  37.710660  POINT (-122.396535107224 37.7106603302503)  14063202264085
# 3  37.730093  POINT (-122.400130573297 37.7300925390327)  15038325904134
# 4  90.000000                           POINT (-120.5 90)   4075398065020
# 5  37.789882  POINT (-122.386667033903 37.7898821569191)   4085512260170
# 6  37.716879    POINT (-122.38750147945 37.716878646429)   6608519171000
# 7  90.000000                           POINT (-120.5 90)   5090840407021
# 8  37.739902   POINT (-122.399686082806 37.739901780585)   9076806426031
# 9  37.773927  POINT (-122.412933062384 37.7739274524819)  11102767604134

# %%
import calendar
df_foc_crimes=df[df.Category.isin(focuscrimes)].groupby(['DayOfWeek','Category'])['IncidntNum'].count()
df_foc_crimes=df_foc_crimes.reindex(list(calendar.day_name ), level='DayOfWeek')

# %%
a=0
plt.figure(figsize=(30, 50))
fig, ax = plt.subplots(nrows=7, ncols=2, sharex=True,figsize=(20,15))

for i in focuscrimes:
    b=a%7
    c=a%2
    ax[b,c].bar(df_foc_crimes[:,i].index ,df_foc_crimes[:,i])
    ax[b,c].legend([i],loc=2)
    a+=1
plt.show()

# %% [markdown]
# The months. We can also check if some months are worse by counting up number of crimes in Jan, Feb, ..., Dec. Did you see any surprises there?

# %%
df.Date=pd.to_datetime(df.Date, format='%m/%d/%Y', errors='coerce')

# %%
df['Month'] = df['Date'].map(lambda x: calendar.month_abbr[x.month])

# %%
df_foc_crimes_month=df[df.Category.isin(focuscrimes)].groupby(['Month','Category'])['IncidntNum'].count()
df_foc_crimes_month=df_foc_crimes_month.reindex(list(calendar.month_abbr ), level='Month')

# %%
a=0
plt.figure(figsize=(30, 50))
fig, ax = plt.subplots(nrows=7, ncols=2, sharex=True,figsize=(20,15))

for i in focuscrimes:
    b=a%7
    c=a%2
    ax[b,c].bar(df_foc_crimes_month[:,i].index ,df_foc_crimes_month[:,i])
    ax[b,c].legend([i],loc=2)
    a+=1
plt.show()

# %% [markdown]
# *The 24 hour cycle*. We'll can also forget about weekday and simply count up the number of each crime-type that occurs in the entire dataset from midnight to 1am, 1am - 2am ... and so on. Again: Give me a couple of comments on what you see.

# %%
df['Time'] = [x + ':00' for x in df['Time']]

# %%
df['TimeInt']=pd.to_timedelta(df.Time, unit='hours').dt.floor('H')
df['HourInt']=  df['TimeInt']/ np.timedelta64(1, 'h')
df.head()
#df_timeint=df[df.Category.isin(focuscrimes)].groupby([df.TimeInt.dt.floor('60min'),'Category'])['Category'].count()
# Out:
#    IncidntNum        Category                 Descript  DayOfWeek       Date  \
# 0   146196161    NON-CRIMINAL            LOST PROPERTY    Tuesday 2014-09-23
# 1   150045675         ASSAULT                  BATTERY   Thursday 2015-01-15
# 2   140632022  SUSPICIOUS OCC  INVESTIGATIVE DETENTION  Wednesday 2014-07-30
# 3   150383259         ASSAULT                  BATTERY   Saturday 2015-05-02
# 4    40753980  OTHER OFFENSES         RECKLESS DRIVING     Friday 2004-07-02
#
#        Time PdDistrict      Resolution                   Address           X  \
# 0  01:00:00   SOUTHERN            NONE    800 Block of BRYANT ST -122.403405
# 1  17:00:00    TARAVAL            NONE  1800 Block of VICENTE ST -122.485604
# 2  09:32:00    BAYVIEW            NONE  100 Block of GILLETTE AV -122.396535
# 3  23:10:00    BAYVIEW  ARREST, BOOKED   2400 Block of PHELPS ST -122.400131
# 4  13:43:00    BAYVIEW            NONE   I-280 / CESAR CHAVEZ ST -120.500000
#
#            Y                                    Location            PdId  \
# 0  37.775421   POINT (-122.403404791479 37.775420706711)  14619616171000
# 1  37.738821   POINT (-122.48560378101 37.7388214326705)  15004567504134
# 2  37.710660  POINT (-122.396535107224 37.7106603302503)  14063202264085
# 3  37.730093  POINT (-122.400130573297 37.7300925390327)  15038325904134
# 4  90.000000                           POINT (-120.5 90)   4075398065020
#
#   Month  TimeInt  HourInt
# 0   Sep 01:00:00      1.0
# 1   Jan 17:00:00     17.0
# 2   Jul 09:00:00      9.0
# 3   May 23:00:00     23.0
# 4   Jul 13:00:00     13.0

# %%
df_timeint=df[df.Category.isin(focuscrimes)].groupby(['HourInt','Category'])['Category'].count()
df_timeint.head()
# Out:
# HourInt  Category
# 0.0      ASSAULT                        10855
#          BURGLARY                        3496
#          DISORDERLY CONDUCT               525
#          DRIVING UNDER THE INFLUENCE      716
#          DRUG/NARCOTIC                   3775
# Name: Category, dtype: int64

# %%
a=0
plt.figure(figsize=(30, 50))
fig, ax = plt.subplots(nrows=7, ncols=2, sharex=True,figsize=(20,15))

for i in focuscrimes:
    b=a%7
    c=a%2
    ax[b,c].bar(df_timeint[:,i].index ,df_timeint[:,i])
    ax[b,c].legend([i],loc=2)
    a+=1
plt.show()

# %% [markdown]
# Hours of the week. But by looking at just 24 hours, we may be missing some important trends that can be modulated by week-day, so let's also check out the 168 hours of the week. So let's see the number of each crime-type Monday night from midninght to 1am, Monday night from 1am-2am - all the way to Sunday night from 11pm to midnight.

# %%
days = dict(zip(calendar.day_name, range(7))); 

df['Day_nr'] = df['DayOfWeek'].map(lambda x: days[x])

df['Interval168']=df['Day_nr']*24+df['HourInt']
df.head()
# Out:
#    IncidntNum        Category                 Descript  DayOfWeek       Date  \
# 0   146196161    NON-CRIMINAL            LOST PROPERTY    Tuesday 2014-09-23
# 1   150045675         ASSAULT                  BATTERY   Thursday 2015-01-15
# 2   140632022  SUSPICIOUS OCC  INVESTIGATIVE DETENTION  Wednesday 2014-07-30
# 3   150383259         ASSAULT                  BATTERY   Saturday 2015-05-02
# 4    40753980  OTHER OFFENSES         RECKLESS DRIVING     Friday 2004-07-02
#
#        Time PdDistrict      Resolution                   Address           X  \
# 0  01:00:00   SOUTHERN            NONE    800 Block of BRYANT ST -122.403405
# 1  17:00:00    TARAVAL            NONE  1800 Block of VICENTE ST -122.485604
# 2  09:32:00    BAYVIEW            NONE  100 Block of GILLETTE AV -122.396535
# 3  23:10:00    BAYVIEW  ARREST, BOOKED   2400 Block of PHELPS ST -122.400131
# 4  13:43:00    BAYVIEW            NONE   I-280 / CESAR CHAVEZ ST -120.500000
#
#            Y                                    Location            PdId  \
# 0  37.775421   POINT (-122.403404791479 37.775420706711)  14619616171000
# 1  37.738821   POINT (-122.48560378101 37.7388214326705)  15004567504134
# 2  37.710660  POINT (-122.396535107224 37.7106603302503)  14063202264085
# 3  37.730093  POINT (-122.400130573297 37.7300925390327)  15038325904134
# 4  90.000000                           POINT (-120.5 90)   4075398065020
#
#   Month  TimeInt  HourInt  Day_nr  Interval168
# 0   Sep 01:00:00      1.0       1         25.0
# 1   Jan 17:00:00     17.0       3         89.0
# 2   Jul 09:00:00      9.0       2         57.0
# 3   May 23:00:00     23.0       5        143.0
# 4   Jul 13:00:00     13.0       4        109.0

# %%
df_timeint168=df[df.Category.isin(focuscrimes)].groupby(['Interval168','Category'])['Category'].count()

# %%
a=0
plt.figure(figsize=(30, 50))
fig, ax = plt.subplots(nrows=7, ncols=2, sharex=True,figsize=(20,15))

for i in focuscrimes:
    b=a%7
    c=a%2
    ax[b,c].bar(df_timeint168[:,i].index ,df_timeint168[:,i])
    ax[b,c].legend([i],loc=2)
    a+=1
plt.show()

# %% [markdown]
# The next thing we'll be looking into is how crimes break down across the 10 districts in San Francisco.
#
# > *Exercises*: The types of crime and how they take place across San Francisco's police districts.
# >
# >  * So now we'll be combining information about `PdDistrict` and `Category` to explore differences between SF's >neighborhoods. First, simply list the names of SF's 10 police districts.
# >  * Which has the most crimes? Which has the most focus crimes?
# >  * Next, we want to generate a slightly more complicated graphic. I'm interested to know if there are certain crimes >that happen much more in certain neighborhoods than what's typical. Below I describe how to get that plot going
# >    - First, we need to calculate the relative probabilities of seeing each type of crime in the dataset as a whole. > That's simply a normalized version of [this plot](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/categoryhist.png). Let's call it `P(crime)`.
# >    - Next, we calculate that same probability distribution _but for each PD district_, let's call that `P(crime|district)`.
# >    - Now we look at the ratio `P(crime|district)/P(crime)`. That ratio is equal to 1 if the crime occurs at the same level within a district as in the city as a whole. If it's greater than one, it means that the crime occurs _more frequently_ within that district. If it's smaller than one, it means that the crime is _rarer within the district in question_ than in the city as a whole.
# >    - For each district plot these ratios for the 14 focus crimes. My plot looks like this
# >      ![Histograms](https://raw.githubusercontent.com/suneman/socialdataanalysis2019/master/files/conditional.png)
# >    - Comment on the top crimes in _Tenderloin_, _Mission_, and _Richmond_. Does this fit with the impression you get of these neighborhoods on Wikipedia?
#
# **Comment**. Notice how much awesome datascience (i.e. learning about interesting real-world crime patterns) we can get out by simply counting and plotting (and looking at ratios). Pretty great, right?

# %% [markdown]
# So now we'll be combining information about PdDistrict and Category to explore differences between SF's >neighborhoods. First, simply list the names of SF's 10 police districts.

# %%
df['PdDistrict'].unique()
# Out:
# array(['SOUTHERN', 'TARAVAL', 'BAYVIEW', 'TENDERLOIN', 'NORTHERN',
#        'INGLESIDE', 'RICHMOND', 'MISSION', 'CENTRAL', 'PARK', nan],
#       dtype=object)

# %% [markdown]
# Which has the most crimes? Which has the most focus crimes?

# %%
df.groupby('PdDistrict')['IncidntNum'].count()
# Out:
# PdDistrict
# BAYVIEW       221000
# CENTRAL       226255
# INGLESIDE     194180
# MISSION       300076
# NORTHERN      272713
# PARK          125479
# RICHMOND      116818
# SOUTHERN      399785
# TARAVAL       166971
# TENDERLOIN    191746
# Name: IncidntNum, dtype: int64

# %%
df[df.Category.isin(focuscrimes)].groupby('PdDistrict')['IncidntNum'].count().sort_values(ascending=False)
# Out:
# PdDistrict
# SOUTHERN      231125
# NORTHERN      175525
# MISSION       167757
# CENTRAL       142378
# BAYVIEW       118026
# TENDERLOIN    108085
# INGLESIDE     107654
# TARAVAL        92254
# PARK           69397
# RICHMOND       68452
# Name: IncidntNum, dtype: int64

# %% [markdown]
# * Next, we want to generate a slightly more complicated graphic. I'm interested to know if there are certain crimes >that happen much more in certain neighborhoods than what's typical. Below I describe how to get that plot going
# >    - First, we need to calculate the relative probabilities of seeing each type of crime in the dataset as a whole. > That's simply a normalized version of [this plot](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/categoryhist.png). Let's call it `P(crime)`.
# >    - Next, we calculate that same probability distribution _but for each PD district_, let's call that `P(crime|district)`.
# >    - Now we look at the ratio `P(crime|district)/P(crime)`. That ratio is equal to 1 if the crime occurs at the same level within a district as in the city as a whole. If it's greater than one, it means that the crime occurs _more frequently_ within that district. If it's smaller than one, it means that the crime is _rarer within the district in question_ than in the city as a whole.
# >    - For each district plot these ratios for the 14 focus crimes. My plot looks like this
#
# >    - Comment on the top crimes in _Tenderloin_, _Mission_, and _Richmond_. Does this fit with the impression you get of these neighborhoods on Wikipedia?

# %%
p_crime=df.Category.value_counts()/df.IncidntNum.count()
p_crime
# Out:
# LARCENY/THEFT                  0.216904
# OTHER OFFENSES                 0.139663
# NON-CRIMINAL                   0.107594
# ASSAULT                        0.087897
# VEHICLE THEFT                  0.057156
# DRUG/NARCOTIC                  0.054008
# VANDALISM                      0.052396
# WARRANTS                       0.045769
# BURGLARY                       0.041328
# SUSPICIOUS OCC                 0.036317
# MISSING PERSON                 0.029327
# ROBBERY                        0.025222
# FRAUD                          0.018755
# SECONDARY CODES                0.011662
# FORGERY/COUNTERFEITING         0.010406
# WEAPON LAWS                    0.010038
# TRESPASS                       0.008780
# PROSTITUTION                   0.007540
# STOLEN PROPERTY                0.005368
# SEX OFFENSES, FORCIBLE         0.005301
# DISORDERLY CONDUCT             0.004533
# DRUNKENNESS                    0.004436
# RECOVERED VEHICLE              0.003935
# DRIVING UNDER THE INFLUENCE    0.002561
# KIDNAPPING                     0.002414
# RUNAWAY                        0.002004
# LIQUOR LAWS                    0.001843
# ARSON                          0.001775
# EMBEZZLEMENT                   0.001349
# LOITERING                      0.001097
# SUICIDE                        0.000583
# FAMILY OFFENSES                0.000534
# BAD CHECKS                     0.000418
# BRIBERY                        0.000367
# EXTORTION                      0.000335
# SEX OFFENSES, NON FORCIBLE     0.000195
# GAMBLING                       0.000157
# PORNOGRAPHY/OBSCENE MAT        0.000027
# TREA                           0.000006
# Name: Category, dtype: float64

# %%
p_crime_district=df.groupby(['Category','PdDistrict'])['IncidntNum'].count()/df.groupby('PdDistrict')['IncidntNum'].count()
p_crime_district
# Out:
# Category       PdDistrict
# ARSON          BAYVIEW       0.004525
#                CENTRAL       0.001215
#                INGLESIDE     0.002384
#                MISSION       0.001446
#                NORTHERN      0.001415
#                PARK          0.001251
#                RICHMOND      0.001935
#                SOUTHERN      0.001211
#                TARAVAL       0.002042
#                TENDERLOIN    0.000861
# ASSAULT        BAYVIEW       0.112271
#                CENTRAL       0.077824
#                INGLESIDE     0.113148
#                MISSION       0.095946
#                NORTHERN      0.077217
#                PARK          0.068832
#                RICHMOND      0.067258
#                SOUTHERN      0.078327
#                TARAVAL       0.082242
#                TENDERLOIN    0.098641
# BAD CHECKS     BAYVIEW       0.000330
#                CENTRAL       0.000570
#                INGLESIDE     0.000407
#                MISSION       0.000307
#                NORTHERN      0.000510
#                PARK          0.000255
#                RICHMOND      0.000565
#                SOUTHERN      0.000440
#                TARAVAL       0.000599
#                TENDERLOIN    0.000203
#                                ...
# VEHICLE THEFT  BAYVIEW       0.076362
#                CENTRAL       0.044198
#                INGLESIDE     0.106216
#                MISSION       0.057765
#                NORTHERN      0.054343
#                PARK          0.075750
#                RICHMOND      0.082427
#                SOUTHERN      0.028563
#                TARAVAL       0.083937
#                TENDERLOIN    0.012407
# WARRANTS       BAYVIEW       0.046421
#                CENTRAL       0.031389
#                INGLESIDE     0.031872
#                MISSION       0.053993
#                NORTHERN      0.040438
#                PARK          0.043513
#                RICHMOND      0.021615
#                SOUTHERN      0.055090
#                TARAVAL       0.024202
#                TENDERLOIN    0.086307
# WEAPON LAWS    BAYVIEW       0.019629
#                CENTRAL       0.005869
#                INGLESIDE     0.014636
#                MISSION       0.011817
#                NORTHERN      0.007411
#                PARK          0.007308
#                RICHMOND      0.006532
#                SOUTHERN      0.007544
#                TARAVAL       0.008397
#                TENDERLOIN    0.010749
# Name: IncidntNum, Length: 387, dtype: float64

# %%
p_crime_district.div(p_crime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-d06ff577d2c5> in <module>
# ----> 1 p_crime_district[0].div(p_crime)
#       2
#
# AttributeError: 'numpy.float64' object has no attribute 'div'

# %% [markdown]
# ## Part 4: Visualizing Geo-data
# Finally, we will draw on the fact that the crime data has lots of exciting geo-data attached. We'll take our inspiration from the implementation shown in the [following article](https://towardsdatascience.com/mapping-geograph-data-in-python-610a963d2d7f) for plotting the GPS data. The article describes how you can visualize geo-data using the `Pandas` and `Matplotlib` packages.
#
# > *Exercise:* We will try to find out where it is safest to leave your car on a Sunday.
# > * Step 0: Read the [tutorial](https://towardsdatascience.com/mapping-geograph-data-in-python-610a963d2d7f) to get a sense of the flow of things.
# > * Start your own work by downloading the [GeoJSON](https://wiki.fileformat.com/gis/geojson/) file [**here**](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/sfpddistricts.geojson).
# > * There are a number of formats for geographical areas, and the article uses *ShapeFiles*, so you will have to convert GeoJSON (one geo-spatial file formate) to ShapeFiles (another geo-spatial file formate), [see the stackoverflow topic](https://stackoverflow.com/a/44050383). Hint: The idea is to is to import the `subprocess` package and copy the last two lines of the solution.
# > * Now, play around with the functions in the 6-9 parts of the article. See if you can generate something like the plot below
# ![heat map](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/heat_maps_simple.png)
# > Take a moment to congratulate yourself. You now know how to select and format shapefiles!
# > * Now, we can focus on our main goal: *determine the districts where you should (and should not) leave your car on Sundays*. (Or stated differently, count up the number of thefts.)
# > * To do so, first:
# >  * Filter the crime dataset by the `DayOfWeek` category and also choose the appropriate crime category.
# >  * Aggregate data by police district.
# > * The result should look more or less like the plot below.
# >   - You do not have to change the color pallete ... or put the names of the districts above the map (as it requires that you change some parts of the functions: `plot_districts_data`, `plot_map_fill_multiples_ids_tone` and `calc_color`) ... but if you feel confident with Python - go for it!
# ![heat map](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/sf_heatmap.png)
# > * Based on your map, where should you park the car for it to be safest? And where's the worst place?
# > *Try this for Extra credit:*
# > * Create plots for the same crime type, but different days -> comment on the results
#
# (Credit: Thank you to TA Germans Savcisens for helping put this exercise together)

# %%
import urllib, geojson, gdal, subprocess

# %%
url= ' https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/sfpddistricts.geojson'
response = urllib.request.urlopen(url)
data = geojson.loads(response.read())

with open('data.geojson', 'w') as f:
    geojson.dump(data, f)

args = ['ogr2ogr', '-f', 'ESRI Shapefile', 'destination_data.shp', 'data.geojson']
subprocess.Popen(args)

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(10,6))

# %%
# %matplotlib inline

# %%
shp_path = "destination_data.shp"
sf = shp.Reader(shp_path)

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (10, 4)

# %%
df.sample(5)
# Out:
#    OBJECTID    DISTRICT COMPANY  \
# 1         2    SOUTHERN       B
# 9        10  TENDERLOIN       J
# 0         1     CENTRAL       A
# 3         4     MISSION       D
# 7         8     TARAVAL       I
#
#                                               coords
# 1  [(-122.388219, 37.789996), (-122.388077, 37.79...
# 9  [(-122.417949, 37.786023), (-122.416543, 37.78...
# 0  [(-122.405321, 37.806868), (-122.404401, 37.80...
# 3  [(-122.408017, 37.769405), (-122.407672, 37.76...
# 7  [(-122.455521, 37.710987), (-122.455597, 37.71...

# %%
def plot_shape(id, s=None):
    """ PLOTS A SINGLE SHAPE """
    plt.figure()
    ax = plt.axes()
    ax.set_aspect('equal')
    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points),1))
    y_lat = np.zeros((len(shape_ex.points),1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    plt.plot(x_lon,y_lat) 
    x0 = np.mean(x_lon)
    y0 = np.mean(y_lat)
    plt.text(x0, y0, s, fontsize=10)
    # use bbox (bounding box) to set plot limits
    plt.xlim(shape_ex.bbox[0],shape_ex.bbox[2])
    return x0, y0

# %%
district = 'SOUTHERN'
dist_id = df[df.DISTRICT == district].index.array[0]
plot_shape(dist_id, district)
# Out:
# (-122.37273756654123, 37.811491403010606)

# %%
def plot_map(sf, x_lim = None, y_lim = None, figsize = (11,9)):
    '''
    Plot map with lim coordinates
    '''
    plt.figure(figsize = figsize)
    id=0
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        plt.plot(x, y, 'k')
        
        if (x_lim == None) & (y_lim == None):
            x0 = np.mean(x)
            y0 = np.mean(y)
            plt.text(x0, y0, id, fontsize=10)
        id = id+1
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
plot_map(sf)

# %%
def plot_map2(id, sf, x_lim = None, y_lim = None, figsize=(11,9)):
    '''
    Plot map with lim coordinates
    '''
   
    plt.figure(figsize = figsize)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        plt.plot(x, y, 'k')
        
    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points),1))
    y_lat = np.zeros((len(shape_ex.points),1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    plt.plot(x_lon,y_lat, 'r', linewidth=3) 
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
y_lim = (37.84,37.70) # latitude 
x_lim = (-122.52, -122.34) # longitude
plot_map(sf, x_lim, y_lim)

# %%
plot_map2(2, sf)

# %%
def plot_map_fill(id, sf, x_lim = None, 
                          y_lim = None, 
                          figsize = (11,9), 
                          color = 'r'):
    '''
    Plot map with lim coordinates
    '''
    
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
        
    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points),1))
    y_lat = np.zeros((len(shape_ex.points),1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    ax.fill(x_lon,y_lat, color)
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
plot_map_fill(1, sf, color='g')
plot_map_fill(2, sf, color='g')

# %%
def plot_map_fill_multiples_ids(title, comuna, sf, 
                                               x_lim = None, 
                                               y_lim = None, 
                                               figsize = (11,9), 
                                               color = 'r'):
    '''
    Plot map with lim coordinates
    '''
    
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color)
             
        x0 = np.mean(x_lon)
        y0 = np.mean(y_lat)
        plt.text(x0, y0, id, fontsize=10)
    
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
district_id = [0, 1, 2, 3, 4, 5, 6]
plot_map_fill_multiples_ids("Multiple Shapes", 
                            district_id, sf, color = 'b')

# %%
# Out:
#          IncidntNum        Category  \
# 1620326    80250849  OTHER OFFENSES
# 1501626   130633886  OTHER OFFENSES
# 1637642   100682459   LARCENY/THEFT
# 1291797    91093755         ASSAULT
# 1766222   130404875    NON-CRIMINAL
# 533736     81173577   VEHICLE THEFT
# 245957     96076336    NON-CRIMINAL
# 176172    150192470  SUSPICIOUS OCC
# 1561439    30938512   LARCENY/THEFT
# 706686     90791441   DRUG/NARCOTIC
#
#                                                Descript  DayOfWeek       Date  \
# 1620326                               TRAFFIC VIOLATION   Saturday 2008-03-08
# 1501626  FALSE PERSONATION TO RECEIVE MONEY OR PROPERTY     Monday 2013-07-29
# 1637642                    PETTY THEFT FROM LOCKED AUTO     Friday 2010-07-23
# 1291797                                         BATTERY     Friday 2009-10-23
# 1766222                       CIVIL SIDEWALKS, CITATION     Friday 2013-05-17
# 533736                                STOLEN AUTOMOBILE   Saturday 2008-11-01
# 245957                                    LOST PROPERTY  Wednesday 2009-08-26
# 176172                            SUSPICIOUS OCCURRENCE    Tuesday 2015-03-03
# 1561439                     PETTY THEFT FROM A BUILDING     Friday 2003-08-08
# 706686                          POSSESSION OF MARIJUANA    Tuesday 2009-08-04
#
#              Time  PdDistrict      Resolution                  Address  \
# 1620326  23:35:00     BAYVIEW  ARREST, BOOKED   1500 Block of PALOU AV
# 1501626  09:00:00    SOUTHERN            NONE   800 Block of MARKET ST
# 1637642  15:00:00     BAYVIEW            NONE      LANE ST / THOMAS AV
# 1291797  17:12:00     MISSION            NONE     MISSION ST / 26TH ST
# 1766222  08:40:00        PARK   ARREST, CITED   MASONIC AV / HAIGHT ST
# 533736   13:30:00     CENTRAL            NONE    2600 Block of HYDE ST
# 245957   11:15:00    SOUTHERN            NONE  100 Block of STEUART ST
# 176172   08:55:00     TARAVAL            NONE    1200 Block of 37TH AV
# 1561439  20:00:00    RICHMOND            NONE   5600 Block of GEARY BL
# 706686   16:06:00  TENDERLOIN   ARREST, CITED     200 Block of TURK ST
#
#                   X          Y                                    Location  \
# 1620326 -122.390060  37.733432   POINT (-122.390060175267 37.733432175289)
# 1501626 -122.407634  37.784189  POINT (-122.407633520742 37.7841893501425)
# 1637642 -122.391292  37.730412  POINT (-122.391291614892 37.7304116196649)
# 1291797 -122.418137  37.749041  POINT (-122.418137290501 37.7490413093633)
# 1766222 -122.445347  37.770208    POINT (-122.4453467866 37.7702081959172)
# 533736  -122.420159  37.805036  POINT (-122.420158500372 37.8050363545139)
# 245957  -122.392350  37.792645  POINT (-122.392349764257 37.7926450897756)
# 176172  -122.496527  37.763327  POINT (-122.496527079269 37.7633265275807)
# 1561439 -122.479938  37.780436  POINT (-122.479938185209 37.7804355312399)
# 706686  -122.413238  37.782843  POINT (-122.413237516676 37.7828430233213)
#
#                    PdId Month  TimeInt  HourInt  Day_nr  Interval168
# 1620326   8025084965015   Mar 23:00:00     23.0       5        143.0
# 1501626  13063388609029   Jul 09:00:00      9.0       0          9.0
# 1637642  10068245906243   Jul 15:00:00     15.0       4        111.0
# 1291797   9109375504134   Oct 17:00:00     17.0       4        113.0
# 1766222  13040487564002   May 08:00:00      8.0       4        104.0
# 533736    8117357707021   Nov 13:00:00     13.0       5        133.0
# 245957    9607633671000   Aug 11:00:00     11.0       2         59.0
# 176172   15019247064070   Mar 08:00:00      8.0       1         32.0
# 1561439   3093851206302   Aug 20:00:00     20.0       4        116.0
# 706686    9079144116010   Aug 16:00:00     16.0       1         40.0

# %% [markdown]
# > Take a moment to congratulate yourself. You now know how to select and format shapefiles!
# > * Now, we can focus on our main goal: *determine the districts where you should (and should not) leave your car on Sundays*. (Or stated differently, count up the number of thefts.)
# > * To do so, first:
# >  * Filter the crime dataset by the `DayOfWeek` category and also choose the appropriate crime category.
# >  * Aggregate data by police district.
# > * The result should look more or less like the plot below.
# >   - You do not have to change the color pallete ... or put the names of the districts above the map (as it requires that you change some parts of the functions: `plot_districts_data`, `plot_map_fill_multiples_ids_tone` and `calc_color`) ... but if you feel confident with Python - go for it!
# ![heat map](https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/sf_heatmap.png)
# > * Based on your map, where should you park the car for it to be safest? And where's the worst place?
# > *Try this for Extra credit:*
# > * Create plots for the same crime type, but different days -> comment on the results

# %%
df_togeo=df.loc[(df['Day_nr']==6) & (df['Category']=='VEHICLE THEFT')]

# %%
df_togeo_group=df_togeo.groupby(['PdDistrict'])['PdDistrict'].count()

# %%
df_togeo_group
# Out:
# PdDistrict
# BAYVIEW       2344
# CENTRAL       1506
# INGLESIDE     2855
# MISSION       2406
# NORTHERN      2006
# PARK          1329
# RICHMOND      1368
# SOUTHERN      1569
# TARAVAL       1954
# TENDERLOIN     357
# Name: PdDistrict, dtype: int64

# %%
def calc_color(data, color=None):
        if color   == 1: 
            color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0'] 
            colors = 'Purples'
        elif color == 2: 
            color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']
            colors = 'YlGnBu'
        elif color == 3: 
            color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525'] 
            colors = 'Greys'
        elif color == 9: 
            color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            
            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404'] 
            colors = 'YlOrBr'
        new_data, bins = pd.qcut(data, 6, retbins=True, 
        labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return color_ton, bins;

# %%
def plot_comunas_data(sf, title, comunas, data=None, 
                      color=None, print_id=False):
    '''
    Plot map with selected comunes, using specific color
    '''
    
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    comuna_id = []
    for i in comunas:
        #i = conv_comuna(i).upper()
        comuna_id.append(df[df.DISTRICT == i.upper()].index.array[0])
    plot_map_fill_multiples_ids_tone(sf, title, comuna_id, 
                                     print_id, 
                                     color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (11,9));

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (11,9)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %%
print_id = True # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_comunas_data(sf, 'South', [df_togeo_group.index[i] for i in range(len(df_togeo_group))], df_togeo_group, color_pallete, print_id)
# Out:
# 1: 357 => 1347
# 2: 1348 => 1505
# 3: 1506 => 1760
# 4: 1761 => 2005
# 5: 2006 => 2374
# 6: 2375 => 2854
#
#    1   2   3   4   5   6

# %%
[df_togeo_group.index[i] for i in range(len(df_togeo_group))]
# Out:
# ['BAYVIEW',
#  'CENTRAL',
#  'INGLESIDE',
#  'MISSION',
#  'NORTHERN',
#  'PARK',
#  'RICHMOND',
#  'SOUTHERN',
#  'TARAVAL',
#  'TENDERLOIN']
